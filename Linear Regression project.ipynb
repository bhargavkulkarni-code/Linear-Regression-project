# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fmcg=pd.read_csv('C:\\Users\\bharg\\Desktop\\Bhargav\ExportSales.csv')
fmcg
# Out:
#            ID        Date   Category  Invoice Number  Product Code  \
# 0     2529604  2019-04-28  Category5             267      30011006
# 1     2529605  2019-04-29  Category5             302      30011006
# 2     2529606  2019-05-13  Category5             507      30011006
# 3     2529607  2019-06-01  Category5             795      30011006
# 4     2529608  2019-07-03  Category5            1184      30011006
# ...       ...         ...        ...             ...           ...
# 7806  2537410  2022-09-14  Category7             221      30006046
# 7807  2537411  2022-09-14  Category7             221      30006045
# 7808  2537412  2022-09-19  Category7             222      30006045
# 7809  2537413  2022-09-19  Category7             223      30006003
# 7810  2537414  2022-09-19  Category7             223      30006030
#
#       Customer Code Destenation   QTY  Total Price
# 0               612         IRQ   750    3334.8225
# 1               514         BHR   400    3032.8240
# ...

# %%
fmcg=fmcg.rename(columns={'Destenation':"Destination"})
fmcg
# Out:
#            ID        Date   Category  Invoice Number  Product Code  \
# 0     2529604  2019-04-28  Category5             267      30011006
# 1     2529605  2019-04-29  Category5             302      30011006
# 2     2529606  2019-05-13  Category5             507      30011006
# 3     2529607  2019-06-01  Category5             795      30011006
# 4     2529608  2019-07-03  Category5            1184      30011006
# ...       ...         ...        ...             ...           ...
# 7806  2537410  2022-09-14  Category7             221      30006046
# 7807  2537411  2022-09-14  Category7             221      30006045
# 7808  2537412  2022-09-19  Category7             222      30006045
# 7809  2537413  2022-09-19  Category7             223      30006003
# 7810  2537414  2022-09-19  Category7             223      30006030
#
#       Customer Code Destination   QTY  Total Price
# 0               612         IRQ   750    3334.8225
# 1               514         BHR   400    3032.8240
# ...

# %%
fmcg.duplicated().sum()
# Out:
# 0

# %%
fmcg.isnull().sum()
# Out:
# ID                  0
# Date                0
# Category            0
# Invoice Number      0
# Product Code        0
# Customer Code       0
# Destination       110
# QTY                 0
# Total Price         0
# dtype: int64

# %%
numerical=[fea for fea in fmcg.columns if fmcg[fea].dtypes!=object]
numerical
# Out:
# ['ID', 'Invoice Number', 'Product Code', 'Customer Code', 'QTY', 'Total Price']

# %%
categorical=[fea for fea in fmcg.columns if fmcg[fea].dtypes==object]
categorical
# Out:
# ['Date', 'Category', 'Destination']

# %%
# fmcg data can be classified in to 2 types one is numerical data and another is categorical data

# %%
fmcgnumerical=fmcg[numerical]
fmcgnumerical
# Out:
#            ID  Invoice Number  Product Code  Customer Code   QTY  Total Price
# 0     2529604             267      30011006            612   750    3334.8225
# 1     2529605             302      30011006            514   400    3032.8240
# 2     2529606             507      30011006            513   100     749.9520
# 3     2529607             795      30011006              5   100     556.8170
# 4     2529608            1184      30011006            560    20      39.4460
# ...       ...             ...           ...            ...   ...          ...
# 7806  2537410             221      30006046              7  1203   13073.6025
# 7807  2537411             221      30006045              7  1087   11812.9725
# 7808  2537412             222      30006045             19  3300   36204.3000
# 7809  2537413             223      30006003            603  4182   38566.4040
# 7810  2537414             223      30006030            603   526    6356.1840
#
# [7811 rows x 6 columns]

# %%
# fmcg numerical data doesnot have null values

# %%
fmcgcategorical=fmcg[categorical]
fmcgcategorical
# Out:
#             Date   Category Destination
# 0     2019-04-28  Category5         IRQ
# 1     2019-04-29  Category5         BHR
# 2     2019-05-13  Category5         BHR
# 3     2019-06-01  Category5         SYC
# 4     2019-07-03  Category5         AFG
# ...          ...        ...         ...
# 7806  2022-09-14  Category7         IRQ
# 7807  2022-09-14  Category7         IRQ
# 7808  2022-09-19  Category7         IRQ
# 7809  2022-09-19  Category7         AZE
# 7810  2022-09-19  Category7         AZE
#
# [7811 rows x 3 columns]

# %%
fmcgcategorical=fmcgcategorical.fillna(fmcgcategorical.mode().iloc[0])
fmcgcategorical
# Out:
#             Date   Category Destination
# 0     2019-04-28  Category5         IRQ
# 1     2019-04-29  Category5         BHR
# 2     2019-05-13  Category5         BHR
# 3     2019-06-01  Category5         SYC
# 4     2019-07-03  Category5         AFG
# ...          ...        ...         ...
# 7806  2022-09-14  Category7         IRQ
# 7807  2022-09-14  Category7         IRQ
# 7808  2022-09-19  Category7         IRQ
# 7809  2022-09-19  Category7         AZE
# 7810  2022-09-19  Category7         AZE
#
# [7811 rows x 3 columns]

# %%
# fmcg categorical null data  filled with mode

# %%
fmcgnumerical.isnull().sum()
# Out:
# ID                0
# Invoice Number    0
# Product Code      0
# Customer Code     0
# QTY               0
# Total Price       0
# dtype: int64

# %%
fmcgcategorical.isnull().sum()
# Out:
# Date           0
# Category       0
# Destination    0
# dtype: int64

# %%
fmcgcategorical['Category']=fmcgcategorical['Category'].replace('Category1',1).replace('Category2',2).replace('Category3',3).replace('Category4',4).replace('Category5',5).replace('Category6',6).replace('Category7',7).replace('Category8',8).replace('Category9',9).replace('Category10',10)
fmcgcategorical['Category']=fmcgcategorical['Category'].astype('int64')

# %%
n=fmcgnumerical['QTY']

# %%
x=pd.concat([n,fmcgcategorical['Category']],axis=1)
x
# Out:
#        QTY  Category
# 0      750         5
# 1      400         5
# 2      100         5
# 3      100         5
# 4       20         5
# ...    ...       ...
# 7806  1203         7
# 7807  1087         7
# 7808  3300         7
# 7809  4182         7
# 7810   526         7
#
# [7811 rows x 2 columns]

# %%
y=fmcgnumerical['Total Price']
y
# Out:
# 0        3334.8225
# 1        3032.8240
# 2         749.9520
# 3         556.8170
# 4          39.4460
#            ...
# 7806    13073.6025
# 7807    11812.9725
# 7808    36204.3000
# 7809    38566.4040
# 7810     6356.1840
# Name: Total Price, Length: 7811, dtype: float64

# %%
# x is independent variable

# %%
# y is dependent variable

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=12)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((5467, 2), (5467,), (2344, 2), (2344,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction=lr.predict(x_test)
y_prediction
# Out:
# array([ 1216.87462413,   988.30190393, 14297.76716407, ...,
#         1543.40708156,   955.64865818,   870.74792397])

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_prediction)
r_squared=r2_score(y_test,y_prediction)
r_squared
# Out:
# 0.6613680807015287

# %%
from math import sqrt
rmse=sqrt(mse)
print('mean squared error :',mse)
print('mean squared error :',rmse)
print('mean squared error :',r_squared)
# Out:
# mean squared error : 8381910.370239595
# mean squared error : 2895.1529096473637
# mean squared error : 0.6613680807015287

# %%
combined_actual_and_predicted_data=pd.DataFrame({'actual':y_test,'predicted':y_prediction})
combined_actual_and_predicted_data
# Out:
#            actual     predicted
# 2137    473.86000   1216.874624
# 2126    248.11410    988.301904
# 7668  19289.60000  14297.767164
# 7799   4041.75000   2523.004454
# 2554      6.74500    204.619416
# ...           ...           ...
# 5012    849.44650    851.153681
# 5867  12839.87981  16096.955266
# 1855    829.28000   1543.407082
# 3164    418.53350    955.648658
# 7501   3422.00000    870.747924
#
# [2344 rows x 2 columns]
